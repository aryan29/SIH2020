# %%
# %tensorflow_version 1.x
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
   raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
print(tf.__version__)
'''import os
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.experimental.TPUStrategy(resolver)'''
# Out:
# Found GPU at: /device:GPU:0
# 1.15.2
# "import os\nresolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])\ntf.config.experimental_connect_to_cluster(resolver)\n# This is the TPU initialization code that has to be at the beginning.\ntf.tpu.experimental.initialize_tpu_system(resolver)\nstrategy = tf.distribute.experimental.TPUStrategy(resolver)"

# %%
# %cd '/content/drive/My Drive/root/'
# Out:
# /content/drive/My Drive/root

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 53, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 37838 (delta 18), reused 29 (delta 2), pack-reused 37785
# Receiving objects: 100% (37838/37838), 522.79 MiB | 14.54 MiB/s, done.
# Resolving deltas: 100% (25304/25304), done.
# Checking out files: 100% (2565/2565), done.

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# !pip install Cython
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 33 not upgraded.
# Need to get 1,818 kB of archives.
# ...

# %%
# %cd /content/drive/My Drive/root/models/research/
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content/drive/My Drive/root/models/research
# object_detection/protos/input_reader.proto: warning: Import object_detection/protos/image_resizer.proto but not used.

# %%
import os
os.environ['PYTHONPATH'] += ':/content/drive/My Drive/root/models/research/:/content/drive/My Drive/root/models/research/slim'

# %%
import time, psutil, os
Start = time.time()- psutil.boot_time()
Left= 12*3600 - Start
print('Time remaining for this session is: ', Left/3600)
# Out:
# Time remaining for this session is:  11.963280696670214

# %%
# !python setup.py build
# !python setup.py install
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/__init__.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/export_inference_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib_tf1_test.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/exporter_lib_tf2_test.py -> build/lib/object_detection
# copying object_detection/exporter_lib_v2.py -> build/lib/object_detection
# copying object_detection/exporter_main_v2.py -> build/lib/object_detection
# ...

# %%
# %cd /content/drive/My Drive/root/models/research/object_detection/builders/
# !python model_builder_tf1_test.py
# Out:
# /content/drive/My Drive/root/models/research/object_detection/builders
# Running tests under Python 3.6.9: /usr/bin/python3
# [ RUN      ] ModelBuilderTF1Test.test_create_context_rcnn_from_config_with_params(True)
# [       OK ] ModelBuilderTF1Test.test_create_context_rcnn_from_config_with_params(True)
# [ RUN      ] ModelBuilderTF1Test.test_create_context_rcnn_from_config_with_params(False)
# [       OK ] ModelBuilderTF1Test.test_create_context_rcnn_from_config_with_params(False)
# [ RUN      ] ModelBuilderTF1Test.test_create_experimental_model
# [       OK ] ModelBuilderTF1Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF1Test.test_create_faster_rcnn_from_config_with_crop_feature(True)
# [       OK ] ModelBuilderTF1Test.test_create_faster_rcnn_from_config_with_crop_feature(True)
# [ RUN      ] ModelBuilderTF1Test.test_create_faster_rcnn_from_config_with_crop_feature(False)
# ...

# %%
# %cd /content/drive/My Drive/root/models/research
# Out:
# /content/drive/My Drive/root/models/research

# %%
#with strategy.scope():
# !python object_detection/model_main.py --pipeline_config_path=ssd_mobilenet_v1_coco.config \
--model_dir='/content/drive/My Drive/sih'\
# Out:
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0711 13:09:46.221645 140382436120448 model_lib.py:717] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0711 13:09:46.221880 140382436120448 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0711 13:09:46.221964 140382436120448 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: 1
# I0711 13:09:46.222044 140382436120448 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: 1
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0711 13:09:46.222127 140382436120448 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# INFO:tensorflow:Maybe overwriting load_pretrained: True
# I0711 13:09:46.222196 140382436120448 config_util.py:552] Maybe overwriting load_pretrained: True
# ...
